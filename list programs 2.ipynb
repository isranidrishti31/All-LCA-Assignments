# %%
#program to print storage
s_name=input("enter a name")
s_address=input("address")
s_contact=int(input("Phone number"))
s_mother_tounge=input("mother tounge")

s_school_name=input("school name")
s_year=int(input("year"))
s_panel=input("panel")
s_roll_number=int(input("roll number"))

print("\n"*10)
print(s_name)
print(s_address)
print(s_contact)
print(s_mother_tounge)
print(s_school_name)
print(s_year)
print(s_panel)
print(s_roll_number)
# Out:
# enter a name drishti
# address pimpri
# Phone number 1234567890
# mothertounge sindhi
# school name jai hind
# year 2026
# panel 2
# roll number 67
# drishti
# pimpri
# 1234567890
# sindhi
# jai hind
# 2026
# 2
# 67

# %%
#highest marks of the student of 3 subjects
s_name=input("name")
s_roll_number=float(input("roll_number"))
s_m=float(input("enter your mathematics marks"))
s_p=float(input("enter your physics marks"))
s_c=float(input("enter your chemistry marks"))

percentage=(s_m+s_p+s_c)/3
print(f"the percentage is {percentage}")

if s_m>=s_p and s_m>=s_c:
    print(f"highest marks are{s_m}")
elif s_p>=s_m and s_p>= s_c:
     print(f"highest marks are{s_p}")
else:
      print(f"highest marks are{s_c}")
# Out:
# name drishti
# roll_number 67
# enter your mathematics marks 100
# enter your physics marks 80
# enter your chemistry marks 90
# the percentage is 90.0
# highest marks are100.0

# %%
#reverse the number
num=int(input("enter a number"))
reverse=0
while num>0:
    digit=num%10
    reverse=reverse*10+digit
    num=num//10

print("Reverse=",reverse)
# Out:
# enter a number 67
# Reverse= 76

# %%
for i in range(1):
    number=int(input("Enter a number:"))
    cube=number**3
print("cube=",cube)
# Out:
# Enter a number: 45
# cube= 91125

# %%
#leap year
year=int(input("enter a year"))

if year % 400==0:
    print("the year is leap year")
elif year % 100==0:
    print("the year is not a leap year")
