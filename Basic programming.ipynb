# %%
# Q1.Write a program to create list of 5 integers and display the list items.Access individual elements through index
numbers= [10,15,20,25,30]
print("List:", numbers)
print("First element:", numbers[0])
print("Second element:", numbers[1])
print("Third element:", numbers[2])
print("Fourth element:", numbers[3])
print("Fifth element:", numbers[4])
# Out:
# List: [10, 15, 20, 25, 30]
# First element: 10
# Second element: 15
# Third element: 20
# Fourth element: 25
# Fifth element: 30

# %%
# Q2. Write a new program to append a new item to the end of the list
numbers.append("60")
numbers
# Out:
# [10, 15, 20, 25, 30, '60']

# %%
# Q3 Inverted list
numbers = [10,15,20,25,30]
print("original list",numbers)
numbers.reverse()
print("reversed list", numbers)
# Out:
# original list [10, 15, 20, 25, 30]
# reversed list [30, 25, 20, 15, 10]

# %%
#Q4.occurance
element= int(input("enter the element to search:"))
count = numbers.count(element)
print("Number of occurances;",count)
# Out:
# enter the element to search: 16
# Number of occurances; 0

# %%
#Q5. adding of lists
list1 = [10,20,30]
list2 = [40,50,60]

list2 = list1+list2
print("list1:",list1)
print("list2:",list2)
# Out:
# list1: [10, 20, 30]
# list2: [10, 20, 30, 40, 50, 60]

# %%
#Q6. Insertion of numbers
numbers = [5,10,15,20,25,30]
print("original list:", numbers)
numbers.insert(16,35)
print("after insertion:", numbers)
# Out:
# original list: [5, 10, 15, 20, 25, 30]
# after insertion: [5, 10, 15, 20, 25, 30, 35]

# %%
#Q7 index remove
numbers= [5,10,15,20,25]
index= int(input("Enter the index to remove:"))
numbers.pop(index)
print("list after remoal:", numbers)
# Out:
# Enter the index to remove: 2
# list after remoal: [5, 10, 20, 25]

# %%
#Q8 REMOVAL
numbers=[10,20,30,40,50]
element = int(input("enter the element to remove:"))
numbers.remove(element)
print("List after  removal:", numbers)
# Out:
# enter the element to remove: 10
# List after  removal: [20, 30, 40, 50]

# %%
#Simple calculator
num1 = float(input("enter first number:"))
num2 = float(input("enter second number:"))
print("\nChoose an operation:,1.Add, 2.Subtract, 3.Multiplication, 4.Division")
choice = int(input("enter your choice (1-4:"))

if choice ==1:
    print("result=",num1+num2)

elif choice == 2:
     print("result=",num1-num2)

elif choice == 3:
    print("result=",num1*num2)

elif choice == 4:
    if num2!=0:
      print("result=",num1/num2)

    else:
        print("error:cannot divide by zero")

else:
  print ("invalid choice!")
# Out:
# enter first number: 50
# enter second number: 10
# Choose an operation:,1.Add, 2.Subtract, 3.Multiplication, 4.Division
# enter your choice (1-4: 2
# result= 40.0
